# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
(X_full_train, y_full_train), (X_test, y_test) = keras.datasets.mnist.load_data()
X_full_train = X_full_train / 255.
X_test = X_test / 255.
X_train, X_valid = X_full_train[:-5000], X_full_train[-5000:]
y_train, y_valid = y_full_train[:-5000], y_full_train[-5000:] 

X_train.shape
# Out:
# (55000, 28, 28)

# %%
X_train = X_train[..., np.newaxis]
X_valid = X_valid[..., np.newaxis]
X_test = X_test[..., np.newaxis]

X_train.shape
# Out:
# (55000, 28, 28, 1)

# %%
keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

model = keras.models.Sequential([
    keras.layers.Conv2D(32, kernel_size=3, padding='same', activation='relu'),
    keras.layers.Conv2D(64, kernel_size=3, padding='same', activation='relu'),
    keras.layers.MaxPool2D(),
    keras.layers.Flatten(),
    keras.layers.Dropout(0.25),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='nadam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, validation_data=(X_valid, y_valid))
model.evaluate(X_test, y_test)
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 13s 6ms/step - loss: 0.3723 - accuracy: 0.8836 - val_loss: 0.0481 - val_accuracy: 0.9870
# Epoch 2/10
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0799 - accuracy: 0.9757 - val_loss: 0.0367 - val_accuracy: 0.9904
# Epoch 3/10
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0545 - accuracy: 0.9823 - val_loss: 0.0359 - val_accuracy: 0.9902
# Epoch 4/10
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0487 - accuracy: 0.9841 - val_loss: 0.0347 - val_accuracy: 0.9910
# Epoch 5/10
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0402 - accuracy: 0.9872 - val_loss: 0.0347 - val_accuracy: 0.9904
# Epoch 6/10
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.0339 - accuracy: 0.9886 - val_loss: 0.0408 - val_accuracy: 0.9904
# Epoch 7/10
# ...
